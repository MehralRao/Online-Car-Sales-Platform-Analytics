# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
df=pd.read_csv('Car Data.csv')

# %%
df
# Out:
#       Car ID      Brand     Model  Year   Color  Mileage  Price       Location
# 0          1     Toyota     Camry  2018   White    45000  18000    Los Angeles
# 1          2      Honda     Civic  2019    Blue    35000  16000       New York
# 2          3       Ford     Focus  2017  Silver    55000  14000        Chicago
# 3          4  Chevrolet     Cruze  2016     Red    60000  12000          Miami
# 4          5    Hyundai   Elantra  2018   Black    40000  15000  San Francisco
# ...      ...        ...       ...   ...     ...      ...    ...            ...
# 1995    1996    Hyundai  Palisade  2019  Silver    65000  22000  San Francisco
# 1996    1997     Toyota    Sienna  2018     Red    55000  16000         Dallas
# 1997    1998      Honda       Fit  2018    Gray    50000  14000        Atlanta
# 1998    1999       Ford    Fusion  2017   White    55000  19000        Phoenix
# 1999    2000  Chevrolet    Malibu  2016    Blue    30000  23000        Houston
#
# [2000 rows x 8 columns]

# %%
print(df.isnull().sum())
# Out:
# Car ID      0
# Brand       0
# Model       0
# Year        0
# Color       0
# Mileage     0
# Price       0
# Location    0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Car ID       int64
# Brand       object
# Model       object
# Year         int64
# Color       object
# Mileage      int64
# Price        int64
# Location    object
# dtype: object

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df['Brand'].unique()
# Out:
# array(['Toyota', 'Honda', 'Ford', 'Chevrolet', 'Hyundai'], dtype=object)

# %%
df.columns
# Out:
# Index(['Car ID', 'Brand', 'Model', 'Year', 'Color', 'Mileage', 'Price',
#        'Location'],
#       dtype='object')

# %%
brand_counts = df['Brand'].value_counts()
print(brand_counts)
# Out:
# Brand
# Toyota       438
# Honda        411
# Ford         384
# Chevrolet    384
# Hyundai      383
# Name: count, dtype: int64

# %%
model_counts = df['Model'].value_counts()
print(model_counts)
# Out:
# Model
# Civic     109
# Fusion     82
# Camry      82
# Cruze      55
# Pilot      55
#          ...
# Rav7        2
# Rav6        2
# Rav5        2
# Rav4        2
# Rav31       1
# Name: count, Length: 68, dtype: int64

# %%
year_counts = df['Year'].value_counts()
print(year_counts)
# Out:
# Year
# 2016    347
# 2015    342
# 2017    340
# 2019    339
# 2018    317
# 2020    315
# Name: count, dtype: int64

# %%
color_counts = df['Color'].value_counts()
print(color_counts)
# Out:
# Color
# White     411
# Blue      383
# Black     329
# Silver    328
# Red       301
# Gray      220
# Yellow     28
# Name: count, dtype: int64

# %%
price_counts = df['Price'].value_counts()
print(price_counts)
# Out:
# Price
# 18000    198
# 14000    170
# 12000    169
# 19000    142
# 22000    141
# 15000    141
# 17000    140
# 16000    114
# 23000    113
# 25000    112
# 27000    112
# 21000    112
# 20000     84
# 24000     84
# 28000     56
# 26000     56
# 29000     56
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#             Car ID         Year       Mileage         Price
# count  2000.000000  2000.000000   2000.000000   2000.000000
# mean   1000.500000  2017.454500  47452.500000  19605.000000
# std     577.494589     1.704812  11016.279906   4777.592249
# min       1.000000  2015.000000  25000.000000  12000.000000
# 25%     500.750000  2016.000000  40000.000000  16000.000000
# 50%    1000.500000  2017.000000  50000.000000  19000.000000
# 75%    1500.250000  2019.000000  55000.000000  23000.000000
# max    2000.000000  2020.000000  70000.000000  29000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Car ID    2000 non-null   int64
#  1   Brand     2000 non-null   object
#  2   Model     2000 non-null   object
#  3   Year      2000 non-null   int64
#  4   Color     2000 non-null   object
#  5   Mileage   2000 non-null   int64
#  6   Price     2000 non-null   int64
#  7   Location  2000 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 125.1+ KB

# %%
df['Units Available'] = [random.randint(1, 5) for _ in range(len(df))]

# %%
df
# Out:
#       Car ID      Brand     Model  Year   Color  Mileage  Price  \
# 0          1     Toyota     Camry  2018   White    45000  18000
# 1          2      Honda     Civic  2019    Blue    35000  16000
# 2          3       Ford     Focus  2017  Silver    55000  14000
# 3          4  Chevrolet     Cruze  2016     Red    60000  12000
# 4          5    Hyundai   Elantra  2018   Black    40000  15000
# ...      ...        ...       ...   ...     ...      ...    ...
# 1995    1996    Hyundai  Palisade  2019  Silver    65000  22000
# 1996    1997     Toyota    Sienna  2018     Red    55000  16000
# 1997    1998      Honda       Fit  2018    Gray    50000  14000
# 1998    1999       Ford    Fusion  2017   White    55000  19000
# 1999    2000  Chevrolet    Malibu  2016    Blue    30000  23000
#
#            Location  Units Available
# 0       Los Angeles                3
# 1          New York                5
# 2           Chicago                3
# 3             Miami                1
# ...

# %%
df['Inventory Value'] = df['Price'] * df['Units Available']

# %%
df
# Out:
#       Car ID      Brand     Model  Year   Color  Mileage  Price  \
# 0          1     Toyota     Camry  2018   White    45000  18000
# 1          2      Honda     Civic  2019    Blue    35000  16000
# 2          3       Ford     Focus  2017  Silver    55000  14000
# 3          4  Chevrolet     Cruze  2016     Red    60000  12000
# 4          5    Hyundai   Elantra  2018   Black    40000  15000
# ...      ...        ...       ...   ...     ...      ...    ...
# 1995    1996    Hyundai  Palisade  2019  Silver    65000  22000
# 1996    1997     Toyota    Sienna  2018     Red    55000  16000
# 1997    1998      Honda       Fit  2018    Gray    50000  14000
# 1998    1999       Ford    Fusion  2017   White    55000  19000
# 1999    2000  Chevrolet    Malibu  2016    Blue    30000  23000
#
#            Location  Units Available  Inventory Value
# 0       Los Angeles                3            54000
# 1          New York                5            80000
# ...

# %%
print('Columns Explanation:\n')
print("1. 'Units Available': Represents the number of cars of a particular model that are currently in stock (inventory)")
print("2. 'Inventory Value': This shows the total value of the cars available for a specific model. It is calculated by multiplying the price of one car by the number of cars available.")
# Out:
# Columns Explanation:
#
# 1. 'Units Available': Represents the number of cars of a particular model that are currently in stock (inventory)
# 2. 'Inventory Value': This shows the total value of the cars available for a specific model. It is calculated by multiplying the price of one car by the number of cars available.

# %%
print('Total Cars Availabe: ', df['Units Available'].sum())
# Out:
# Total Cars Availabe:  6077

# %%
def mileage_category(mileage):
    if mileage < 30000:
        return 'Low'
    elif mileage < 60000:
        return 'Medium'
    else:
        return 'High'
df['Mileage Category'] = df['Mileage'].apply(mileage_category)

# %%
df
# Out:
#       Car ID      Brand     Model  Year   Color  Mileage  Price  \
# 0          1     Toyota     Camry  2018   White    45000  18000
# 1          2      Honda     Civic  2019    Blue    35000  16000
# 2          3       Ford     Focus  2017  Silver    55000  14000
# 3          4  Chevrolet     Cruze  2016     Red    60000  12000
# 4          5    Hyundai   Elantra  2018   Black    40000  15000
# ...      ...        ...       ...   ...     ...      ...    ...
# 1995    1996    Hyundai  Palisade  2019  Silver    65000  22000
# 1996    1997     Toyota    Sienna  2018     Red    55000  16000
# 1997    1998      Honda       Fit  2018    Gray    50000  14000
# 1998    1999       Ford    Fusion  2017   White    55000  19000
# 1999    2000  Chevrolet    Malibu  2016    Blue    30000  23000
#
#            Location  Units Available  Inventory Value Mileage Category
# 0       Los Angeles                3            54000           Medium
# ...

# %%
total_cars_per_brand = df.groupby('Brand')['Units Available'].sum().reset_index()
print(total_cars_per_brand)
# Out:
#        Brand  Units Available
# 0  Chevrolet             1215
# 1       Ford             1166
# 2      Honda             1206
# 3    Hyundai             1176
# 4     Toyota             1314

# %%
# Total Inventory Value and Units Available per Brand
brand_performance = df.groupby('Brand').agg({
    'Inventory Value': 'sum',  # Sum of Inventory Value for each brand
    'Units Available': 'sum'  # Sum of Units Available for each brand
}).reset_index()

# Total Inventory Value and Units Available per Model
model_performance = df.groupby('Model').agg({
    'Inventory Value': 'sum',  # Sum of Inventory Value for each model
    'Units Available': 'sum'  # Sum of Units Available for each model
}).reset_index()

print(brand_performance)
print('\n')
print(model_performance)
# Out:
#        Brand  Inventory Value  Units Available
# 0  Chevrolet         23970000             1215
# 1       Ford         23081000             1166
# 2      Honda         23502000             1206
# 3    Hyundai         23269000             1176
# 4     Toyota         25675000             1314
#
#
#        Model  Inventory Value  Units Available
# 0    4Runner          3073000              159
# 1     Accent          1724000               90
# 2     Accord          3030000              150
# 3     Avalon          1648000               80
# 4       CR-V          3068000              150
# ..       ...              ...              ...
# 63     Tahoe          3094000              162
# 64  Traverse          3679000              188
# 65    Tucson          1526000               75
# 66     Venue          3151000              167
# 67     Yaris          3157000              171
#
# [68 rows x 3 columns]

# %%
def price_category(price):
    if price < 15000:
        return 'Low'
    elif price < 25000:
        return 'Medium'
    else:
        return 'High'
df['Price Category'] = df['Price'].apply(price_category)

# %%
df
# Out:
#       Car ID      Brand     Model  Year   Color  Mileage  Price  \
# 0          1     Toyota     Camry  2018   White    45000  18000
# 1          2      Honda     Civic  2019    Blue    35000  16000
# 2          3       Ford     Focus  2017  Silver    55000  14000
# 3          4  Chevrolet     Cruze  2016     Red    60000  12000
# 4          5    Hyundai   Elantra  2018   Black    40000  15000
# ...      ...        ...       ...   ...     ...      ...    ...
# 1995    1996    Hyundai  Palisade  2019  Silver    65000  22000
# 1996    1997     Toyota    Sienna  2018     Red    55000  16000
# 1997    1998      Honda       Fit  2018    Gray    50000  14000
# 1998    1999       Ford    Fusion  2017   White    55000  19000
# 1999    2000  Chevrolet    Malibu  2016    Blue    30000  23000
#
#            Location  Units Available  Inventory Value Mileage Category  \
# 0       Los Angeles                3            54000           Medium
# ...

# %%
df[['Brand', 'Location']].groupby('Brand').count()
# Out:
#            Location
# Brand
# Chevrolet       384
# Ford            384
# Honda           411
# Hyundai         383
# Toyota          438

# %%
df.nunique()
# Out:
# Car ID              2000
# Brand                  5
# Model                 68
# Year                   6
# Color                  7
# Mileage               10
# Price                 17
# Location              10
# Units Available        5
# Inventory Value       70
# Mileage Category       3
# Price Category         3
# dtype: int64

# %%
df['Color'].unique()
# Out:
# array(['White', 'Blue', 'Silver', 'Red', 'Black', 'Gray', 'Yellow'],
#       dtype=object)

# %%
plt.rcParams['figure.figsize']  = (30, 12)

plt.subplot(1, 5, 1)
size = df['Color'].value_counts()
labels ='White', 'Blue', 'Silver' ,'Red', 'Black', 'Gray' ,'Yellow'
color = ['White' ,'Blue' ,'Silver' ,'Red', 'Black' ,'Gray' ,'Yellow']
plt.pie(size, colors=color, labels=labels, autopct='%.2f%%')
plt.title('Color Distribution', fontsize=20)
plt.axis('off')
# Out:
# (-1.25, 1.25, -1.25, 1.25)

# %%
df.to_csv('Final Car Data.csv', index=False)

# %%
df2 = pd.read_csv('Final Car Data.csv')

# %%
df2
# Out:
#       Car ID      Brand     Model  Year   Color  Mileage  Price  \
# 0          1     Toyota     Camry  2018   White    45000  18000
# 1          2      Honda     Civic  2019    Blue    35000  16000
# 2          3       Ford     Focus  2017  Silver    55000  14000
# 3          4  Chevrolet     Cruze  2016     Red    60000  12000
# 4          5    Hyundai   Elantra  2018   Black    40000  15000
# ...      ...        ...       ...   ...     ...      ...    ...
# 1995    1996    Hyundai  Palisade  2019  Silver    65000  22000
# 1996    1997     Toyota    Sienna  2018     Red    55000  16000
# 1997    1998      Honda       Fit  2018    Gray    50000  14000
# 1998    1999       Ford    Fusion  2017   White    55000  19000
# 1999    2000  Chevrolet    Malibu  2016    Blue    30000  23000
#
#            Location  Units Available  Inventory Value Mileage Category  \
# 0       Los Angeles                3            54000           Medium
# ...
